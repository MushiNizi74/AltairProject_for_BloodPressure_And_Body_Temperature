# %%
pip install altair vega_datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.  Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      -------------------------------------- 812.8/812.8 kB 1.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 210.8/210.8 kB 2.1 MB/s eta 0:00:00
# ...
#
# ...

# %%
import altair as alt
import pandas as pd

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00639/Maternal%20Health%20Risk%20Data%20Set.csv'
bp =pd.read_csv(url)
bp
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
bp.info
# Out:
# <bound method DataFrame.info of       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]>

# %%
bp['RiskLevel'] = bp['RiskLevel'].replace({'low risk':1, 'mid risk': 2, 'high risk': 3})
bp['RiskLevel']= bp['RiskLevel'].astype('int')
bp.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86          3
# 1   35         140           90  13.0      98.0         70          3
# 2   29          90           70   8.0     100.0         80          3
# 3   30         140           85   7.0      98.0         70          3
# 4   35         120           60   6.1      98.0         76          1

# %%
select_age = alt.selection_single(
    name='select', fields=['Age'], init={'Age': 10},
    bind=alt.binding_range(min=10, max=70, step=5)
)

base1=(alt.Chart(bp, title='Risk factor when Lower BP and Body temp').mark_point(filled=True).encode(
    alt.X('DiastolicBP:Q',scale=alt.Scale(domain=[40,140])),
    alt.Y('BodyTemp:Q', scale=alt.Scale(domain=[90,105])),
    alt.Size('RiskLevel:Q'),
    alt.Color('RiskLevel:N'),
    alt.OpacityValue(0.5),
))

base2=(alt.Chart(bp, title='Risk factor when Higher BP and Body temp').mark_point(filled=True).encode(
    alt.X('SystolicBP:Q',scale=alt.Scale(domain=[60,170])),
    alt.Y('BodyTemp:Q', scale=alt.Scale(domain=[95,100])),
    alt.Size('RiskLevel:Q'),
    alt.Color('RiskLevel:N'),
    alt.OpacityValue(0.5),
))
alt.hconcat(base1, base2).add_selection(select_year).transform_filter(select_year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9008/953570392.py in <module>
#      19     alt.OpacityValue(0.5),
#      20 ))
# ---> 21 alt.hconcat(base1, base2).add_selection(select_year).transform_filter(select_year)
#
# NameError: name 'select_year' is not defined
